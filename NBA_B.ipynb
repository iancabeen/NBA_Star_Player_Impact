# %%
# prompt: import data science libraries, sns set theme, mount drive

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import os

sns.set_theme()

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/MyDrive/DSO 574/NBA Data/'

# %%
files = os.listdir(data_path + 'Combined Files [With Game ID]')
files
# Out:
# ['2016-2017_NBA_PbP_Logs.csv',
#  '2014-2015_NBA_PbP_Logs.csv',
#  '2013-2014_NBA_PbP_Logs.csv',
#  '2015-2016_NBA_PbP_Logs.csv',
#  '2021-2022_NBA_PbP_Logs.csv',
#  '2017-2018_NBA_PbP_Logs.csv',
#  '2019-2020_NBA_PbP_Logs.csv',
#  '2022-2023_NBA_PbP_Logs.csv',
#  '2018-2019_NBA_PbP_Logs.csv',
#  '2020-2021_NBA_PbP_Logs.csv',
#  '2023-2024_NBA_PbP_Logs.csv']

# %%
df = pd.read_csv(data_path + 'Combined Files [With Game ID]/2014-2015_NBA_PbP_Logs.csv')

# %%
new_orleans = df[df['matchup'].apply(lambda x: 'NOP' in x)].copy()
new_orleans['ad_on'] = (new_orleans.iloc[:, 3:14] == 'Anthony Davis').sum(axis=1).astype(bool)
new_orleans['NOP_offense'] = new_orleans.team == 'NOP'
new_orleans['game_min'] = new_orleans.elapsed.apply(lambda x: int(x.split(':')[1]))
new_orleans
# Out:
#          game_id                data_set        date                 a1  \
# 4480    21400323  2014-15 Regular Season  2014-12-10      Anthony Davis
# 4481    21400323  2014-15 Regular Season  2014-12-10      Anthony Davis
# 4482    21400323  2014-15 Regular Season  2014-12-10      Anthony Davis
# 4483    21400323  2014-15 Regular Season  2014-12-10      Anthony Davis
# 4484    21400323  2014-15 Regular Season  2014-12-10      Anthony Davis
# ...          ...                     ...         ...                ...
# 600094  21400311  2014-15 Regular Season  2014-12-09  Amar'e Stoudemire
# 600095  21400311  2014-15 Regular Season  2014-12-09  Amar'e Stoudemire
# 600096  21400311  2014-15 Regular Season  2014-12-09       Cole Aldrich
# 600097  21400311  2014-15 Regular Season  2014-12-09       Cole Aldrich
# 600098  21400311  2014-15 Regular Season  2014-12-09       Cole Aldrich
#
#                a2              a3             a4               a5  \
# 4480    Omer Asik    Jrue Holiday   Luke Babbitt     Tyreke Evans
# 4481    Omer Asik    Jrue Holiday   Luke Babbitt     Tyreke Evans
# 4482    Omer Asik    Jrue Holiday   Luke Babbitt     Tyreke Evans
# 4483    Omer Asik    Jrue Holiday   Luke Babbitt     Tyreke Evans
# 4484    Omer Asik    Jrue Holiday   Luke Babbitt     Tyreke Evans
# ...           ...             ...            ...              ...
# 600094   JR Smith  Pablo Prigioni  Jose Calderon  Carmelo Anthony
# 600095   JR Smith  Pablo Prigioni  Jose Calderon  Carmelo Anthony
# 600096   JR Smith  Pablo Prigioni  Jose Calderon  Carmelo Anthony
# 600097   JR Smith  Pablo Prigioni  Jose Calderon  Carmelo Anthony
# 600098   JR Smith  Pablo Prigioni  Jose Calderon  Carmelo Anthony
#
#                     h1                h2  ... original_x original_y  \
# 4480    Tyson Chandler        J.J. Barea  ...        NaN        NaN
# 4481    Tyson Chandler        J.J. Barea  ...        NaN        NaN
# 4482    Tyson Chandler        J.J. Barea  ...        9.0       98.0
# 4483    Tyson Chandler        J.J. Barea  ...        NaN        NaN
# 4484    Tyson Chandler        J.J. Barea  ...     -168.0      121.0
# ...                ...               ...  ...        ...        ...
# 600094    Tyreke Evans  Dante Cunningham  ...        NaN        NaN
# 600095    Tyreke Evans  Dante Cunningham  ...        NaN        NaN
# 600096    Tyreke Evans  Dante Cunningham  ...        NaN        NaN
# 600097    Tyreke Evans  Dante Cunningham  ...      -15.0        9.0
# 600098    Tyreke Evans  Dante Cunningham  ...        NaN        NaN
#
#        converted_x  converted_y                                  description  \
# 4480           NaN          NaN                                          NaN
# 4481           NaN          NaN   Jump Ball Chandler vs. Davis: Tip to Barea
# 4482          25.9         79.2                     MISS Ellis 10' Jump Shot
# 4483           NaN          NaN                   Asik REBOUND (Off:0 Def:1)
# 4484          41.8         17.1  Davis 21' Jump Shot (2 PTS) (Holiday 1 AST)
# ...            ...          ...                                          ...
# 600094         NaN          NaN              Asik Free Throw 1 of 2 (16 PTS)
# 600095         NaN          NaN                  MISS Asik Free Throw 2 of 2
# 600096         NaN          NaN                Anthony REBOUND (Off:1 Def:7)
# 600097        26.5          5.9              Smith 2' Driving Layup (17 PTS)
# 600098         NaN          NaN                                          NaN
#
#         matchup           game_name ad_on NOP_offense  game_min
# 4480    NOP@DAL  0021400323-NOP@DAL  True       False         0
# 4481    NOP@DAL  0021400323-NOP@DAL  True       False         0
# 4482    NOP@DAL  0021400323-NOP@DAL  True       False         0
# 4483    NOP@DAL  0021400323-NOP@DAL  True        True         0
# 4484    NOP@DAL  0021400323-NOP@DAL  True        True         0
# ...         ...                 ...   ...         ...       ...
# 600094  NYK@NOP  0021400311-NYK@NOP  True        True        11
# 600095  NYK@NOP  0021400311-NYK@NOP  True        True        11
# 600096  NYK@NOP  0021400311-NYK@NOP  True       False        11
# 600097  NYK@NOP  0021400311-NYK@NOP  True       False        11
# 600098  NYK@NOP  0021400311-NYK@NOP  True       False        12
#
# [38088 rows x 49 columns]

# %%
new_orleans.columns
# Out:
# Index(['game_id', 'data_set', 'date', 'a1', 'a2', 'a3', 'a4', 'a5', 'h1', 'h2',
#        'h3', 'h4', 'h5', 'period', 'away_score', 'home_score',
#        'remaining_time', 'elapsed', 'play_length', 'play_id', 'team',
#        'event_type', 'assist', 'away', 'home', 'block', 'entered', 'left',
#        'num', 'opponent', 'outof', 'player', 'points', 'possession', 'reason',
#        'result', 'steal', 'type', 'shot_distance', 'original_x', 'original_y',
#        'converted_x', 'converted_y', 'description', 'matchup', 'game_name',
#        'ad_on', 'NOP_offense', 'game_min'],
#       dtype='object')

# %%
years = ['2021-2022_NBA_PbP_Logs.csv', '2022-2023_NBA_PbP_Logs.csv', '2023-2024_NBA_PbP_Logs.csv']
suns = pd.DataFrame()
for y in years:
  data = pd.read_csv(data_path + 'Combined Files [With Game ID]/' + y)
  suns = pd.concat([suns, data[data['matchup'].apply(lambda x: 'PHX' in x)]])
suns
# Out:
#          game_id                      data_set        date              a1  \
# 2287    22100331        2021-22 Regular Season  2021-12-02  Isaiah Stewart
# 2288    22100331        2021-22 Regular Season  2021-12-02  Isaiah Stewart
# 2289    22100331        2021-22 Regular Season  2021-12-02  Isaiah Stewart
# 2290    22100331        2021-22 Regular Season  2021-12-02  Isaiah Stewart
# 2291    22100331        2021-22 Regular Season  2021-12-02  Isaiah Stewart
# ...          ...                           ...         ...             ...
# 607909  22301228  NBA 2023-2024 Regular Season  2023-12-08    Chris Duarte
# 607910  22301228  NBA 2023-2024 Regular Season  2023-12-08    Chris Duarte
# 607911  22301228  NBA 2023-2024 Regular Season  2023-12-08    Chris Duarte
# 607912  22301228  NBA 2023-2024 Regular Season  2023-12-08    Chris Duarte
# 607913  22301228  NBA 2023-2024 Regular Season  2023-12-08    Chris Duarte
#
#                    a2               a3               a4               a5  \
# 2287    Killian Hayes     Jerami Grant       Saddiq Bey  Cade Cunningham
# 2288    Killian Hayes     Jerami Grant       Saddiq Bey  Cade Cunningham
# 2289    Killian Hayes     Jerami Grant       Saddiq Bey  Cade Cunningham
# 2290    Killian Hayes     Jerami Grant       Saddiq Bey  Cade Cunningham
# 2291    Killian Hayes     Jerami Grant       Saddiq Bey  Cade Cunningham
# ...               ...              ...              ...              ...
# 607909     Keon Ellis  Davion Mitchell  Kessler Edwards   Sasha Vezenkov
# 607910     Keon Ellis  Davion Mitchell  Kessler Edwards   Sasha Vezenkov
# 607911     Keon Ellis  Davion Mitchell  Kessler Edwards   Sasha Vezenkov
# 607912     Keon Ellis  Davion Mitchell  Kessler Edwards   Sasha Vezenkov
# 607913     Keon Ellis  Davion Mitchell  Kessler Edwards   Sasha Vezenkov
#
#                     h1             h2  ... steal                type  \
# 2287     Deandre Ayton  Mikal Bridges  ...   NaN     start of period
# 2288     Deandre Ayton  Mikal Bridges  ...   NaN           jump ball
# 2289     Deandre Ayton  Mikal Bridges  ...   NaN           jump shot
# 2290     Deandre Ayton  Mikal Bridges  ...   NaN   rebound defensive
# 2291     Deandre Ayton  Mikal Bridges  ...   NaN  3pt jump bank shot
# ...                ...            ...  ...   ...                 ...
# 607909  Jordan Goodwin        Bol Bol  ...   NaN          shot clock
# 607910  Jordan Goodwin        Bol Bol  ...   NaN            shooting
# 607911  Jordan Goodwin        Bol Bol  ...   NaN      free throw 1/2
# 607912  Jordan Goodwin        Bol Bol  ...   NaN      free throw 2/2
# 607913  Jordan Goodwin        Bol Bol  ...   NaN       end of period
#
#        shot_distance  original_x  original_y  converted_x converted_y  \
# 2287             NaN         NaN         NaN          NaN         NaN
# 2288             NaN         NaN         NaN          NaN         NaN
# 2289            15.0      -148.0        27.0         10.2        86.3
# 2290             NaN         NaN         NaN          NaN         NaN
# 2291            25.0       105.0       231.0         14.5        28.1
# ...              ...         ...         ...          ...         ...
# 607909           NaN         NaN         NaN          NaN         NaN
# 607910           NaN         NaN         NaN          NaN         NaN
# 607911           NaN         NaN         NaN          NaN         NaN
# 607912           NaN         NaN         NaN          NaN         NaN
# 607913           NaN         NaN         NaN          NaN         NaN
#
#                                         description  matchup  \
# 2287                                            NaN  DET@PHX
# 2288    Jump Ball Ayton vs. Stewart: Tip to Bridges  DET@PHX
# 2289            MISS Ayton 15' Turnaround Jump Shot  DET@PHX
# 2290                    Hayes REBOUND (Off:0 Def:1)  DET@PHX
# 2291              MISS Grant 25' 3PT Jump Bank Shot  DET@PHX
# ...                                             ...      ...
# 607909            Kings Turnover: Shot Clock (T#13)  SAC@PHX
# 607910            Edwards S.FOUL (P1.PN) (B.Taylor)  SAC@PHX
# 607911                Lee Free Throw 1 of 2 (3 PTS)  SAC@PHX
# 607912                Lee Free Throw 2 of 2 (4 PTS)  SAC@PHX
# 607913                                          NaN  SAC@PHX
#
#                  game_name
# 2287    0022100331-DET@PHX
# 2288    0022100331-DET@PHX
# 2289    0022100331-DET@PHX
# 2290    0022100331-DET@PHX
# 2291    0022100331-DET@PHX
# ...                    ...
# 607909  0022301228-SAC@PHX
# 607910  0022301228-SAC@PHX
# 607911  0022301228-SAC@PHX
# 607912  0022301228-SAC@PHX
# 607913  0022301228-SAC@PHX
#
# [126873 rows x 46 columns]

# %%
suns['db_on'] = (suns.iloc[:, 3:14] == 'Devin Booker').sum(axis=1).astype(bool)
suns['PHX_offense'] = suns.team == 'PHX'
suns['game_min'] = suns.elapsed.apply(lambda x: int(x.split(':')[1]))
suns['period_min'] = suns.period.astype(str) + '_' + suns.game_min.astype(str)
suns['description'] = suns.description.astype(str)

# %%
suns
# Out:
#          game_id                      data_set        date              a1  \
# 2287    22100331        2021-22 Regular Season  2021-12-02  Isaiah Stewart
# 2288    22100331        2021-22 Regular Season  2021-12-02  Isaiah Stewart
# 2289    22100331        2021-22 Regular Season  2021-12-02  Isaiah Stewart
# 2290    22100331        2021-22 Regular Season  2021-12-02  Isaiah Stewart
# 2291    22100331        2021-22 Regular Season  2021-12-02  Isaiah Stewart
# ...          ...                           ...         ...             ...
# 607909  22301228  NBA 2023-2024 Regular Season  2023-12-08    Chris Duarte
# 607910  22301228  NBA 2023-2024 Regular Season  2023-12-08    Chris Duarte
# 607911  22301228  NBA 2023-2024 Regular Season  2023-12-08    Chris Duarte
# 607912  22301228  NBA 2023-2024 Regular Season  2023-12-08    Chris Duarte
# 607913  22301228  NBA 2023-2024 Regular Season  2023-12-08    Chris Duarte
#
#                    a2               a3               a4               a5  \
# 2287    Killian Hayes     Jerami Grant       Saddiq Bey  Cade Cunningham
# 2288    Killian Hayes     Jerami Grant       Saddiq Bey  Cade Cunningham
# 2289    Killian Hayes     Jerami Grant       Saddiq Bey  Cade Cunningham
# 2290    Killian Hayes     Jerami Grant       Saddiq Bey  Cade Cunningham
# 2291    Killian Hayes     Jerami Grant       Saddiq Bey  Cade Cunningham
# ...               ...              ...              ...              ...
# 607909     Keon Ellis  Davion Mitchell  Kessler Edwards   Sasha Vezenkov
# 607910     Keon Ellis  Davion Mitchell  Kessler Edwards   Sasha Vezenkov
# 607911     Keon Ellis  Davion Mitchell  Kessler Edwards   Sasha Vezenkov
# 607912     Keon Ellis  Davion Mitchell  Kessler Edwards   Sasha Vezenkov
# 607913     Keon Ellis  Davion Mitchell  Kessler Edwards   Sasha Vezenkov
#
#                     h1             h2  ... original_y converted_x converted_y  \
# 2287     Deandre Ayton  Mikal Bridges  ...        NaN         NaN         NaN
# 2288     Deandre Ayton  Mikal Bridges  ...        NaN         NaN         NaN
# 2289     Deandre Ayton  Mikal Bridges  ...       27.0        10.2        86.3
# 2290     Deandre Ayton  Mikal Bridges  ...        NaN         NaN         NaN
# 2291     Deandre Ayton  Mikal Bridges  ...      231.0        14.5        28.1
# ...                ...            ...  ...        ...         ...         ...
# 607909  Jordan Goodwin        Bol Bol  ...        NaN         NaN         NaN
# 607910  Jordan Goodwin        Bol Bol  ...        NaN         NaN         NaN
# 607911  Jordan Goodwin        Bol Bol  ...        NaN         NaN         NaN
# 607912  Jordan Goodwin        Bol Bol  ...        NaN         NaN         NaN
# 607913  Jordan Goodwin        Bol Bol  ...        NaN         NaN         NaN
#
#                                         description  matchup  \
# 2287                                            nan  DET@PHX
# 2288    Jump Ball Ayton vs. Stewart: Tip to Bridges  DET@PHX
# 2289            MISS Ayton 15' Turnaround Jump Shot  DET@PHX
# 2290                    Hayes REBOUND (Off:0 Def:1)  DET@PHX
# 2291              MISS Grant 25' 3PT Jump Bank Shot  DET@PHX
# ...                                             ...      ...
# 607909            Kings Turnover: Shot Clock (T#13)  SAC@PHX
# 607910            Edwards S.FOUL (P1.PN) (B.Taylor)  SAC@PHX
# 607911                Lee Free Throw 1 of 2 (3 PTS)  SAC@PHX
# 607912                Lee Free Throw 2 of 2 (4 PTS)  SAC@PHX
# 607913                                          nan  SAC@PHX
#
#                  game_name  db_on PHX_offense game_min  period_min
# 2287    0022100331-DET@PHX  False       False        0         1_0
# 2288    0022100331-DET@PHX  False        True        0         1_0
# 2289    0022100331-DET@PHX  False        True        0         1_0
# 2290    0022100331-DET@PHX  False       False        0         1_0
# 2291    0022100331-DET@PHX  False       False        0         1_0
# ...                    ...    ...         ...      ...         ...
# 607909  0022301228-SAC@PHX  False       False       11        4_11
# 607910  0022301228-SAC@PHX  False       False       11        4_11
# 607911  0022301228-SAC@PHX  False        True       11        4_11
# 607912  0022301228-SAC@PHX  False        True       11        4_11
# 607913  0022301228-SAC@PHX  False       False       12        4_12
#
# [126873 rows x 50 columns]

# %%
# prompt: generate pivot table on 'db_on', 'PHX_offense', and 'period_min' summing 'home_score' and 'away_score'

pivot_table = pd.pivot_table(suns, values=['home_score', 'away_score'], index=['db_on', 'data_set', 'period_min'], aggfunc='sum').reset_index()
pivot_table['plus_minus'] = pivot_table['home_score'] - pivot_table['away_score']
pivot_table
# Out:
#      db_on           data_set period_min  away_score  home_score  plus_minus
# 0    False   2021-22 Playoffs        1_0           2          12          10
# 1    False   2021-22 Playoffs        1_1          30          45          15
# 2    False   2021-22 Playoffs       1_10        1164        1227          63
# 3    False   2021-22 Playoffs       1_11        1173        1384         211
# 4    False   2021-22 Playoffs       1_12         292         344          52
# ..     ...                ...        ...         ...         ...         ...
# 700   True  NBA 2024 Playoffs        4_5        3199        3327         128
# 701   True  NBA 2024 Playoffs        4_6        5005        5326         321
# 702   True  NBA 2024 Playoffs        4_7        3476        3604         128
# 703   True  NBA 2024 Playoffs        4_8        3450        3552         102
# 704   True  NBA 2024 Playoffs        4_9        3571        3399        -172
#
# [705 rows x 6 columns]

# %%
# prompt:  plot plus minus distribution for both values of db_on on the same plot, remove the bars for each data_set

# Assuming pivot_table is defined as in your previous code

plt.figure(figsize=(12, 6))

for db_on_val in pivot_table['db_on'].unique():
  subset = pivot_table[pivot_table['db_on'] == db_on_val]
  sns.histplot(subset['plus_minus'], label=f'Devin Booker: {db_on_val}', kde=True)

plt.xlabel('Plus Minus')
plt.ylabel('Frequency')
plt.title('Plus Minus Distribution with and without Devin Booker')
plt.legend()
plt.show()

# %% [markdown]
# ### PHX Shot Percentage With and Without DBook, With and Without KD During Regular Season

# %%
suns['kd_on'] = (suns.iloc[:, 3:14] == 'Kevin Durant').sum(axis=1).astype(bool)

# %%
# regular season
suns_off = suns[(suns.PHX_offense) & (suns.data_set.astype(str).apply(lambda x: 'Regular' in x))].copy()
suns_off['misses'] = suns_off.description.apply(lambda x: 'MISS' in x)
suns_off['makes'] = suns_off.description.apply(lambda x: 'PTS' in x) & suns_off.description.astype(str).apply(lambda x: 'Free Throw' not in x)
suns_off.head()
# Out:
#        game_id                data_set        date              a1  \
# 2288  22100331  2021-22 Regular Season  2021-12-02  Isaiah Stewart
# 2289  22100331  2021-22 Regular Season  2021-12-02  Isaiah Stewart
# 2292  22100331  2021-22 Regular Season  2021-12-02  Isaiah Stewart
# 2293  22100331  2021-22 Regular Season  2021-12-02  Isaiah Stewart
# 2298  22100331  2021-22 Regular Season  2021-12-02  Isaiah Stewart
#
#                  a2            a3          a4               a5             h1  \
# 2288  Killian Hayes  Jerami Grant  Saddiq Bey  Cade Cunningham  Deandre Ayton
# 2289  Killian Hayes  Jerami Grant  Saddiq Bey  Cade Cunningham  Deandre Ayton
# 2292  Killian Hayes  Jerami Grant  Saddiq Bey  Cade Cunningham  Deandre Ayton
# 2293  Killian Hayes  Jerami Grant  Saddiq Bey  Cade Cunningham  Deandre Ayton
# 2298  Killian Hayes  Jerami Grant  Saddiq Bey  Cade Cunningham  Deandre Ayton
#
#                  h2  ...                                  description  \
# 2288  Mikal Bridges  ...  Jump Ball Ayton vs. Stewart: Tip to Bridges
# 2289  Mikal Bridges  ...          MISS Ayton 15' Turnaround Jump Shot
# 2292  Mikal Bridges  ...                  Ayton REBOUND (Off:0 Def:1)
# 2293  Mikal Bridges  ...                    MISS Shamet 18' Jump Shot
# 2298  Mikal Bridges  ...                  Ayton REBOUND (Off:0 Def:2)
#
#       matchup           game_name  db_on  PHX_offense  game_min period_min  \
# 2288  DET@PHX  0022100331-DET@PHX  False         True         0        1_0
# 2289  DET@PHX  0022100331-DET@PHX  False         True         0        1_0
# 2292  DET@PHX  0022100331-DET@PHX  False         True         0        1_0
# 2293  DET@PHX  0022100331-DET@PHX  False         True         0        1_0
# 2298  DET@PHX  0022100331-DET@PHX  False         True         1        1_1
#
#       kd_on misses  makes
# 2288  False  False  False
# 2289  False   True  False
# 2292  False  False  False
# 2293  False   True  False
# 2298  False  False  False
#
# [5 rows x 53 columns]

# %%
# prompt: generate pivot table for suns_off for db_on and sum of misses and makes
pivot_table_suns_off_no_kd = pd.pivot_table(suns_off[~suns_off.kd_on], values=['misses', 'makes'], index=['db_on', 'period_min'], aggfunc='sum').reset_index()
pivot_table_suns_off_no_kd['shots'] = pivot_table_suns_off_no_kd['misses'] + pivot_table_suns_off_no_kd['makes']
pivot_table_suns_off_no_kd['shot_pct'] = pivot_table_suns_off_no_kd['makes'] / pivot_table_suns_off_no_kd['shots']
pivot_table_suns_off_no_kd
# Out:
#      db_on period_min  makes  misses  shots  shot_pct
# 0    False        1_0     34      41     75  0.453333
# 1    False        1_1     35      45     80  0.437500
# 2    False       1_10     52      83    135  0.385185
# 3    False       1_11     78     100    178  0.438202
# 4    False       1_12      2      24     26  0.076923
# ..     ...        ...    ...     ...    ...       ...
# 111   True        5_1      3       2      5  0.600000
# 112   True        5_2      1       2      3  0.333333
# 113   True        5_3      1       2      3  0.333333
# 114   True        5_4      0       5      5  0.000000
# 115   True        5_5      0       1      1  0.000000
#
# [116 rows x 6 columns]

# %%
plt.figure(figsize=(12, 6))

for db_on_val in pivot_table_suns_off_no_kd['db_on'].unique():
  subset = pivot_table_suns_off_no_kd[pivot_table_suns_off_no_kd['db_on'] == db_on_val]
  sns.kdeplot(subset['shot_pct'], label=f'Devin Booker On Court: {db_on_val}')

avg_shot_pct = pivot_table_suns_off_no_kd['shot_pct'].mean()
plt.axvline(x=avg_shot_pct, color='red', linestyle='--', label=f'Average Shot Percentage: {avg_shot_pct:.2f}')

plt.xlabel('Shot Percentage')
plt.xlim(0, 1)
plt.ylabel('Density')
plt.ylim(0, 5)
plt.title('Shot Percentage By Minute Distribution With and Without Devin Booker, Without Kevin Durant')
plt.legend()
plt.show()

# %%
 # with kd
pivot_table_suns_off_kd = pd.pivot_table(suns_off[suns_off.kd_on], values=['misses', 'makes'], index=['db_on', 'period_min'], aggfunc='sum').reset_index()
pivot_table_suns_off_kd['shots'] = pivot_table_suns_off_kd['misses'] + pivot_table_suns_off_kd['makes']
pivot_table_suns_off_kd['shot_pct'] = pivot_table_suns_off_kd['makes'] / pivot_table_suns_off_kd['shots']
pivot_table_suns_off_kd
# Out:
#      db_on period_min  makes  misses  shots  shot_pct
# 0    False        1_0     12       8     20  0.600000
# 1    False        1_1     14      16     30  0.466667
# 2    False       1_10     17      19     36  0.472222
# 3    False       1_11     10      19     29  0.344828
# 4    False       1_12      1       2      3  0.333333
# ..     ...        ...    ...     ...    ...       ...
# 116   True        6_1      1       0      1  1.000000
# 117   True        6_2      0       2      2  0.000000
# 118   True        6_3      0       0      0       NaN
# 119   True        6_4      1       1      2  0.500000
# 120   True        6_5      0       0      0       NaN
#
# [121 rows x 6 columns]

# %%
plt.figure(figsize=(12, 5))

for db_on_val in pivot_table_suns_off_no_kd['db_on'].unique():
  subset = pivot_table_suns_off_no_kd[pivot_table_suns_off_no_kd['db_on'] == db_on_val]
  sns.kdeplot(subset['shot_pct'], label=f'Devin Booker On Court: {db_on_val}')

avg_shot_pct = pivot_table_suns_off_no_kd['shot_pct'].mean()
plt.axvline(x=avg_shot_pct, color='red', linestyle='--', label=f'Average Shot Percentage: {avg_shot_pct:.2f}')

plt.xlabel('Shot Percentage')
plt.xlim(0, 1)
plt.ylabel('Density')
plt.ylim(0, 5)
plt.title('Shot Percentage By Minute Distribution With and Without Devin Booker, Without Kevin Durant')
plt.legend()
plt.show()

plt.figure(figsize=(12, 5))

for db_on_val in pivot_table_suns_off_kd['db_on'].unique():
  subset = pivot_table_suns_off_kd[pivot_table_suns_off_kd['db_on'] == db_on_val]
  sns.kdeplot(subset['shot_pct'], label=f'Devin Booker On Court: {db_on_val}')

avg_shot_pct = pivot_table_suns_off_kd['shot_pct'].mean()
plt.axvline(x=avg_shot_pct, color='red', linestyle='--', label=f'Average Shot Percentage: {avg_shot_pct:.2f}')

plt.xlabel('Shot Percentage')
plt.xlim(0, 1)
plt.ylabel('Density')
plt.ylim(0, 5)
plt.title('Shot Percentage By Minute Distribution With and Without Devin Booker, With Kevin Durant')
plt.legend()
plt.show()

# %% [markdown]
# ### Dbook Shot Distribution With and Without KD - 2022-2024

# %%
booker_off_2224 = suns_off[(suns_off.db_on) & (suns_off.data_set.astype(str).apply(lambda x: '23' in x))].copy()
# get only plays where booker is involved in the action
booker_off_2224 = booker_off_2224[booker_off_2224.description.apply(lambda x: 'Booker' in x)]

# %%
booker_off_2224['db_shot'] = (booker_off_2224.description.apply(lambda x: '(Booker' not in x)) \
      & (booker_off_2224['type'].apply(lambda x: 'shot' in x or 'layup' in x or 'fadeaway' in x or 'dunk' in x))

# %%
booker_shot_2224 = booker_off_2224[(booker_off_2224.db_shot) | (booker_off_2224['type'].apply(lambda x: 'free throw' in x or 'technical' in x))].copy()
booker_shot_2224['FT'] = booker_shot_2224['type'].apply(lambda x: 'free throw' in x or 'technical' in x)
booker_shot_2224['FT_make'] = (booker_shot_2224.FT) & (booker_shot_2224.description.apply(lambda x: 'MISS' not in x))
booker_shot_2224['shot'] = ~booker_shot_2224.FT
booker_shot_2224['shot_make'] = booker_shot_2224.shot & (booker_shot_2224.description.apply(lambda x: 'MISS' not in x))

# %%
booker_shot_2224['3PT'] = ((booker_shot_2224.shot_distance >= 22) & (booker_shot_2224['type'].apply(lambda x: '3pt' in x)))
booker_shot_2224['midrange'] = ((booker_shot_2224.shot_distance <= 24) & (booker_shot_2224.shot_distance > 10) & (booker_shot_2224['type'].apply(lambda x: '3pt' not in x)))
booker_shot_2224['close'] = (booker_shot_2224.shot_distance <= 10)

# %%
# prompt: make a pivot for each shot distance category ('3PT', 'midrange', and 'close'), kd_on and summing shot and shot make

pivot_table_shot_distribution = pd.pivot_table(booker_shot_2224, values=['shot', 'shot_make'],
                                              index=['kd_on', '3PT', 'midrange', 'close', 'period_min'],
                                              aggfunc='sum').reset_index()

pivot_table_shot_distribution
# Out:
#      kd_on    3PT  midrange  close period_min  shot  shot_make
# 0    False  False     False  False       1_10     0          0
# 1    False  False     False  False       1_11     0          0
# 2    False  False     False  False        1_2     0          0
# 3    False  False     False  False        1_3     0          0
# 4    False  False     False  False        1_4     0          0
# ..     ...    ...       ...    ...        ...   ...        ...
# 372   True   True     False  False        4_7    14          5
# 373   True   True     False  False        4_8     8          1
# 374   True   True     False  False        4_9     7          3
# 375   True   True     False  False        5_3     1          0
# 376   True   True     False  False        6_2     1          0
#
# [377 rows x 7 columns]

# %%
# prompt: plot 'shot' kde distribution for kd on and off, normalizing y axis, for each category of shot

plt.figure(figsize=(12, 5))

for kd_on_val in pivot_table_shot_distribution['kd_on'].unique():
  for shot_type in ['3PT', 'midrange', 'close']:
    subset = pivot_table_shot_distribution[(pivot_table_shot_distribution['kd_on'] == kd_on_val) & (pivot_table_shot_distribution[shot_type])]
    if not subset.empty:
      shot_pct = subset['shot_make'] / subset['shot']
      sns.kdeplot(subset['shot'], bw_adjust=0.7, label=f'KD On Court: {kd_on_val}, {shot_type}')


plt.xlabel('Shot')
plt.xlim(0, 30)
plt.ylabel('Density')
plt.title('Shot Distribution by Minute by Shot Type With and Without Kevin Durant')
plt.legend()
plt.show()

# %%
# prompt: split the above into 3 plots, one for each shot category

# Assuming pivot_table_shot_distribution is defined as in your previous code

plt.figure(figsize=(16, 6))

for kd_on_val in pivot_table_shot_distribution['kd_on'].unique():
  plt.subplot(1, 3, 1)  # Subplot for 3PT shots
  for shot_type in ['3PT']:
    subset = pivot_table_shot_distribution[(pivot_table_shot_distribution['kd_on'] == kd_on_val) & (pivot_table_shot_distribution[shot_type])]
    if not subset.empty:
      shot_pct = subset['shot_make'] / subset['shot']
      sns.kdeplot(subset['shot'], bw_adjust=0.7, label=f'KD On Court: {kd_on_val}')
  plt.xlabel('Shot Count')
  plt.xlim(0, 30)
  plt.ylabel('Proportion')
  plt.title('Booker 3PT Shot Distribution')
  plt.legend()


  plt.subplot(1, 3, 2)  # Subplot for midrange shots
  for shot_type in ['midrange']:
    subset = pivot_table_shot_distribution[(pivot_table_shot_distribution['kd_on'] == kd_on_val) & (pivot_table_shot_distribution[shot_type])]
    if not subset.empty:
      shot_pct = subset['shot_make'] / subset['shot']
      sns.kdeplot(subset['shot'], bw_adjust=0.7, label=f'KD On Court: {kd_on_val}')
  plt.xlabel('Shot Count')
  plt.xlim(0, 30)
  plt.ylabel('Proportion')
  plt.title('Booker Midrange Shot Distribution')
  plt.legend()


  plt.subplot(1, 3, 3)  # Subplot for close shots
  for shot_type in ['close']:
    subset = pivot_table_shot_distribution[(pivot_table_shot_distribution['kd_on'] == kd_on_val) & (pivot_table_shot_distribution[shot_type])]
    if not subset.empty:
      shot_pct = subset['shot_make'] / subset['shot']
      sns.kdeplot(subset['shot'], bw_adjust=0.7, label=f'KD On Court: {kd_on_val}')
  plt.xlabel('Shot Count')
  plt.xlim(0, 30)
  plt.ylabel('Proportion')
  plt.title('Booker Close Shot Distribution')
  plt.legend(loc='best')

plt.tight_layout()  # Adjust subplot spacing
plt.show()

# %% [markdown]
# # Tyrese Haliburton effect on the Pacers on and off the court

# %%
years = ['2021-2022_NBA_PbP_Logs.csv', '2022-2023_NBA_PbP_Logs.csv', '2023-2024_NBA_PbP_Logs.csv']
ind = pd.DataFrame()
for y in years:
  data = pd.read_csv(data_path + 'Combined Files [With Game ID]/' + y)
  ind = pd.concat([ind, data[data['matchup'].apply(lambda x: 'IND' in x)]])
ind
# Out:
#          game_id                       data_set        date              a1  \
# 3182    22100333         2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# 3183    22100333         2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# 3184    22100333         2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# 3185    22100333         2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# 3186    22100333         2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# ...          ...                            ...         ...             ...
# 601722  22301229  NBA 2023 In-Season Tournament  2023-12-07    Myles Turner
# 601723  22301229  NBA 2023 In-Season Tournament  2023-12-07    Myles Turner
# 601724  22301229  NBA 2023 In-Season Tournament  2023-12-07    Myles Turner
# 601725  22301229  NBA 2023 In-Season Tournament  2023-12-07    Myles Turner
# 601726  22301229  NBA 2023 In-Season Tournament  2023-12-07    Myles Turner
#
#                  a2               a3                 a4             a5  \
# 3182     Kyle Lowry  Duncan Robinson        P.J. Tucker    Tyler Herro
# 3183     Kyle Lowry  Duncan Robinson        P.J. Tucker    Tyler Herro
# 3184     Kyle Lowry  Duncan Robinson        P.J. Tucker    Tyler Herro
# 3185     Kyle Lowry  Duncan Robinson        P.J. Tucker    Tyler Herro
# 3186     Kyle Lowry  Duncan Robinson        P.J. Tucker    Tyler Herro
# ...             ...              ...                ...            ...
# 601722  Buddy Hield      Bruce Brown  Tyrese Haliburton  Aaron Nesmith
# 601723  Buddy Hield      Bruce Brown  Tyrese Haliburton  Aaron Nesmith
# 601724  Buddy Hield      Bruce Brown  Tyrese Haliburton  Aaron Nesmith
# 601725  Buddy Hield      Bruce Brown  Tyrese Haliburton  Aaron Nesmith
# 601726  Buddy Hield      Bruce Brown  Tyrese Haliburton  Aaron Nesmith
#
#                            h1            h2  ...         steal  \
# 3182             Myles Turner  Caris LeVert  ...           NaN
# 3183             Myles Turner  Caris LeVert  ...           NaN
# 3184             Myles Turner  Caris LeVert  ...           NaN
# 3185             Myles Turner  Caris LeVert  ...  Torrey Craig
# 3186             Myles Turner  Caris LeVert  ...           NaN
# ...                       ...           ...  ...           ...
# 601722  Giannis Antetokounmpo   Brook Lopez  ...           NaN
# 601723  Giannis Antetokounmpo   Brook Lopez  ...           NaN
# 601724  Giannis Antetokounmpo   Brook Lopez  ...           NaN
# 601725  Giannis Antetokounmpo   Brook Lopez  ...           NaN
# 601726  Giannis Antetokounmpo   Brook Lopez  ...           NaN
#
#                      type shot_distance  original_x  original_y  converted_x  \
# 3182      start of period           NaN         NaN         NaN          NaN
# 3183            jump ball           NaN         NaN         NaN          NaN
# 3184            jump shot          16.0        17.0       164.0         26.7
# 3185             bad pass           NaN         NaN         NaN          NaN
# 3186            jump shot          19.0      -191.0        18.0          5.9
# ...                   ...           ...         ...         ...          ...
# 601722     free throw 1/2           NaN         NaN         NaN          NaN
# 601723     free throw 2/2           NaN         NaN         NaN          NaN
# 601724      driving layup           3.0       -10.0        27.0         24.0
# 601725  rebound defensive           NaN         NaN         NaN          NaN
# 601726      end of period           NaN         NaN         NaN          NaN
#
#        converted_y                                        description  \
# 3182           NaN                                                NaN
# 3183           NaN         Jump Ball Turner vs. Dedmon: Tip to LeVert
# 3184          72.6  Turner 16' Turnaround Jump Shot (2 PTS) (Brogd...
# 3185           NaN  Craig STEAL (1 STL): Lowry Bad Pass Turnover (...
# 3186          87.2             Duarte 19' Step Back Jump Shot (2 PTS)
# ...            ...                                                ...
# 601722         NaN                    Hield Free Throw 1 of 2 (7 PTS)
# 601723         NaN                    Hield Free Throw 2 of 2 (8 PTS)
# 601724        86.3                    MISS Middleton 3' Driving Layup
# 601725         NaN                        Hield REBOUND (Off:4 Def:7)
# 601726         NaN                                                NaN
#
#         matchup           game_name
# 3182    MIA@IND  0022100333-MIA@IND
# 3183    MIA@IND  0022100333-MIA@IND
# 3184    MIA@IND  0022100333-MIA@IND
# 3185    MIA@IND  0022100333-MIA@IND
# 3186    MIA@IND  0022100333-MIA@IND
# ...         ...                 ...
# 601722  IND@MIL  0022301229-IND@MIL
# 601723  IND@MIL  0022301229-IND@MIL
# 601724  IND@MIL  0022301229-IND@MIL
# 601725  IND@MIL  0022301229-IND@MIL
# 601726  IND@MIL  0022301229-IND@MIL
#
# [124728 rows x 46 columns]

# %%
ind['hali'] = (ind.iloc[:, 3:14] == 'Tyrese Haliburton').sum(axis=1).astype(bool)
ind['IND_offense'] = ind.team == 'IND'
ind['game_min'] = ind.elapsed.apply(lambda x: int(x.split(':')[1]))
ind['period_min'] = ind.period.astype(str) + '_' + ind.game_min.astype(str)
ind['description'] = ind.description.astype(str)

# %%
ind
# Out:
#          game_id                       data_set        date              a1  \
# 3182    22100333         2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# 3183    22100333         2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# 3184    22100333         2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# 3185    22100333         2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# 3186    22100333         2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# ...          ...                            ...         ...             ...
# 601722  22301229  NBA 2023 In-Season Tournament  2023-12-07    Myles Turner
# 601723  22301229  NBA 2023 In-Season Tournament  2023-12-07    Myles Turner
# 601724  22301229  NBA 2023 In-Season Tournament  2023-12-07    Myles Turner
# 601725  22301229  NBA 2023 In-Season Tournament  2023-12-07    Myles Turner
# 601726  22301229  NBA 2023 In-Season Tournament  2023-12-07    Myles Turner
#
#                  a2               a3                 a4             a5  \
# 3182     Kyle Lowry  Duncan Robinson        P.J. Tucker    Tyler Herro
# 3183     Kyle Lowry  Duncan Robinson        P.J. Tucker    Tyler Herro
# 3184     Kyle Lowry  Duncan Robinson        P.J. Tucker    Tyler Herro
# 3185     Kyle Lowry  Duncan Robinson        P.J. Tucker    Tyler Herro
# 3186     Kyle Lowry  Duncan Robinson        P.J. Tucker    Tyler Herro
# ...             ...              ...                ...            ...
# 601722  Buddy Hield      Bruce Brown  Tyrese Haliburton  Aaron Nesmith
# 601723  Buddy Hield      Bruce Brown  Tyrese Haliburton  Aaron Nesmith
# 601724  Buddy Hield      Bruce Brown  Tyrese Haliburton  Aaron Nesmith
# 601725  Buddy Hield      Bruce Brown  Tyrese Haliburton  Aaron Nesmith
# 601726  Buddy Hield      Bruce Brown  Tyrese Haliburton  Aaron Nesmith
#
#                            h1            h2  ... original_y converted_x  \
# 3182             Myles Turner  Caris LeVert  ...        NaN         NaN
# 3183             Myles Turner  Caris LeVert  ...        NaN         NaN
# 3184             Myles Turner  Caris LeVert  ...      164.0        26.7
# 3185             Myles Turner  Caris LeVert  ...        NaN         NaN
# 3186             Myles Turner  Caris LeVert  ...       18.0         5.9
# ...                       ...           ...  ...        ...         ...
# 601722  Giannis Antetokounmpo   Brook Lopez  ...        NaN         NaN
# 601723  Giannis Antetokounmpo   Brook Lopez  ...        NaN         NaN
# 601724  Giannis Antetokounmpo   Brook Lopez  ...       27.0        24.0
# 601725  Giannis Antetokounmpo   Brook Lopez  ...        NaN         NaN
# 601726  Giannis Antetokounmpo   Brook Lopez  ...        NaN         NaN
#
#        converted_y                                        description  \
# 3182           NaN                                                nan
# 3183           NaN         Jump Ball Turner vs. Dedmon: Tip to LeVert
# 3184          72.6  Turner 16' Turnaround Jump Shot (2 PTS) (Brogd...
# 3185           NaN  Craig STEAL (1 STL): Lowry Bad Pass Turnover (...
# 3186          87.2             Duarte 19' Step Back Jump Shot (2 PTS)
# ...            ...                                                ...
# 601722         NaN                    Hield Free Throw 1 of 2 (7 PTS)
# 601723         NaN                    Hield Free Throw 2 of 2 (8 PTS)
# 601724        86.3                    MISS Middleton 3' Driving Layup
# 601725         NaN                        Hield REBOUND (Off:4 Def:7)
# 601726         NaN                                                nan
#
#         matchup           game_name   hali IND_offense game_min  period_min
# 3182    MIA@IND  0022100333-MIA@IND  False       False        0         1_0
# 3183    MIA@IND  0022100333-MIA@IND  False        True        0         1_0
# 3184    MIA@IND  0022100333-MIA@IND  False        True        0         1_0
# 3185    MIA@IND  0022100333-MIA@IND  False       False        0         1_0
# 3186    MIA@IND  0022100333-MIA@IND  False        True        0         1_0
# ...         ...                 ...    ...         ...      ...         ...
# 601722  IND@MIL  0022301229-IND@MIL   True        True       11        4_11
# 601723  IND@MIL  0022301229-IND@MIL   True        True       11        4_11
# 601724  IND@MIL  0022301229-IND@MIL   True       False       11        4_11
# 601725  IND@MIL  0022301229-IND@MIL   True        True       11        4_11
# 601726  IND@MIL  0022301229-IND@MIL   True       False       12        4_12
#
# [124728 rows x 50 columns]

# %%
# prompt: generate pivot table on 'hali', 'IND_offense', and 'period_min' summing 'home_score' and 'away_score'

import pandas as pd
pivot_table_ind = pd.pivot_table(ind, values=['home_score', 'away_score'], index=['hali', 'IND_offense', 'period_min'], aggfunc='sum').reset_index()
pivot_table_ind
# Out:
#       hali  IND_offense period_min  away_score  home_score
# 0    False        False        1_0         245         291
# 1    False        False        1_1        1211        1279
# 2    False        False       1_10       24372       25774
# 3    False        False       1_11       30019       31429
# 4    False        False       1_12       11230       11748
# ..     ...          ...        ...         ...         ...
# 227   True         True        5_1        3599        3601
# 228   True         True        5_2        3954        3963
# 229   True         True        5_3        4530        4524
# 230   True         True        5_4        7680        7698
# 231   True         True        5_5         258         258
#
# [232 rows x 5 columns]

# %%
# prompt: plot plus minus distribution for both values of hali on the same plot, remove the bars for each data_set

import matplotlib.pyplot as plt
# Assuming pivot_table_ind is defined as in your previous code

plt.figure(figsize=(12, 6))

for hali_val in pivot_table_ind['hali'].unique():
    subset = pivot_table_ind[pivot_table_ind['hali'] == hali_val]
    sns.kdeplot(subset['home_score'] - subset['away_score'], label=f'Tyrese Haliburton: {hali_val}')

avg_plus_minus = pivot_table_ind['home_score'] - pivot_table_ind['away_score'].mean()
plt.axvline(x=avg_plus_minus.mean(), color='red', linestyle='--', label=f'Average Plus Minus: {avg_plus_minus.mean():.2f}')

plt.xlabel('Plus Minus')
plt.ylabel('Density')
plt.title('Plus Minus Distribution with and without Tyrese Haliburton')
plt.legend()
plt.show()

# %%
# prompt: add a t-test that compares plus minus with haliburton on court vs haliburton not on court

from scipy import stats

# Assuming pivot_table_ind is defined as in your previous code

hali_on = pivot_table_ind[pivot_table_ind['hali'] == True]['home_score'] - pivot_table_ind[pivot_table_ind['hali'] == True]['away_score']
hali_off = pivot_table_ind[pivot_table_ind['hali'] == False]['home_score'] - pivot_table_ind[pivot_table_ind['hali'] == False]['away_score']

t_statistic, p_value = stats.ttest_ind(hali_on, hali_off)

print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("There is a statistically significant difference in shot percentage with and without Haliburton on the court.")
else:
    print("There is no statistically significant difference in shot percentage with and without Haliburton on the court.")
# Out:
# T-statistic: -3.061920485961009
# P-value: 0.002460917009150967
# There is a statistically significant difference in shot percentage with and without Haliburton on the court.

# %%
ind_off = ind[(ind.IND_offense) & (ind.data_set.astype(str).apply(lambda x: 'Regular' in x))].copy()
ind_off['misses'] = ind_off.description.apply(lambda x: 'MISS' in x)
ind_off['makes'] = ind_off.description.apply(lambda x: 'PTS' in x) & ind_off.description.astype(str).apply(lambda x: 'Free Throw' not in x)
ind_off
# Out:
#          game_id                      data_set        date              a1  \
# 3183    22100333        2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# 3184    22100333        2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# 3186    22100333        2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# 3188    22100333        2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# 3191    22100333        2021-22 Regular Season  2021-12-03  Dewayne Dedmon
# ...          ...                           ...         ...             ...
# 590425  22300284  NBA 2023-2024 Regular Season  2023-12-02      Obi Toppin
# 590426  22300284  NBA 2023-2024 Regular Season  2023-12-02      Obi Toppin
# 590428  22300284  NBA 2023-2024 Regular Season  2023-12-02    Ben Sheppard
# 590429  22300284  NBA 2023-2024 Regular Season  2023-12-02    Ben Sheppard
# 590433  22300284  NBA 2023-2024 Regular Season  2023-12-02    Ben Sheppard
#
#                   a2               a3           a4             a5  \
# 3183      Kyle Lowry  Duncan Robinson  P.J. Tucker    Tyler Herro
# 3184      Kyle Lowry  Duncan Robinson  P.J. Tucker    Tyler Herro
# 3186      Kyle Lowry  Duncan Robinson  P.J. Tucker    Tyler Herro
# 3188      Kyle Lowry  Duncan Robinson  P.J. Tucker    Tyler Herro
# 3191      Kyle Lowry  Duncan Robinson  P.J. Tucker    Tyler Herro
# ...              ...              ...          ...            ...
# 590425  Myles Turner   T.J. McConnell  Bruce Brown  Aaron Nesmith
# 590426  Myles Turner   T.J. McConnell  Bruce Brown  Aaron Nesmith
# 590428  Myles Turner   T.J. McConnell  Bruce Brown  Aaron Nesmith
# 590429  Myles Turner   T.J. McConnell  Bruce Brown  Aaron Nesmith
# 590433  Myles Turner   T.J. McConnell  Bruce Brown  Aaron Nesmith
#
#                       h1            h2  ... converted_y  \
# 3183        Myles Turner  Caris LeVert  ...         NaN
# 3184        Myles Turner  Caris LeVert  ...        72.6
# 3186        Myles Turner  Caris LeVert  ...        87.2
# 3188        Myles Turner  Caris LeVert  ...        73.9
# 3191        Myles Turner  Caris LeVert  ...        88.6
# ...                  ...           ...  ...         ...
# 590425  Jaime Jaquez Jr.  Jimmy Butler  ...         NaN
# 590426  Jaime Jaquez Jr.  Jimmy Butler  ...         5.1
# 590428  Jaime Jaquez Jr.  Jimmy Butler  ...         NaN
# 590429  Jaime Jaquez Jr.  Jimmy Butler  ...         NaN
# 590433  Jaime Jaquez Jr.    Jamal Cain  ...         NaN
#
#                                               description  matchup  \
# 3183           Jump Ball Turner vs. Dedmon: Tip to LeVert  MIA@IND
# 3184    Turner 16' Turnaround Jump Shot (2 PTS) (Brogd...  MIA@IND
# 3186               Duarte 19' Step Back Jump Shot (2 PTS)  MIA@IND
# 3188                     MISS Duarte 18' Pullup Jump Shot  MIA@IND
# 3191              LeVert 2' Layup (2 PTS) (Brogdon 2 AST)  MIA@IND
# ...                                                   ...      ...
# 590425                      Nesmith REBOUND (Off:0 Def:4)  IND@MIA
# 590426                         MISS Nesmith 3PT Jump Shot  IND@MIA
# 590428                           SUB: Sheppard FOR Toppin  IND@MIA
# 590429               Sheppard S.FOUL (P2.PN) (T.Brothers)  IND@MIA
# 590433                 Pacers Turnover: Shot Clock (T#10)  IND@MIA
#
#                  game_name   hali  IND_offense game_min period_min misses  \
# 3183    0022100333-MIA@IND  False         True        0        1_0  False
# 3184    0022100333-MIA@IND  False         True        0        1_0  False
# 3186    0022100333-MIA@IND  False         True        0        1_0  False
# 3188    0022100333-MIA@IND  False         True        1        1_1   True
# 3191    0022100333-MIA@IND  False         True        2        1_2  False
# ...                    ...    ...          ...      ...        ...    ...
# 590425  0022300284-IND@MIA  False         True       11       4_11  False
# 590426  0022300284-IND@MIA  False         True       11       4_11   True
# 590428  0022300284-IND@MIA  False         True       11       4_11  False
# 590429  0022300284-IND@MIA  False         True       11       4_11  False
# 590433  0022300284-IND@MIA  False         True       11       4_11  False
#
#         makes
# 3183    False
# 3184     True
# 3186     True
# 3188    False
# 3191     True
# ...       ...
# 590425  False
# 590426  False
# 590428  False
# 590429  False
# 590433  False
#
# [55766 rows x 52 columns]

# %%
# prompt: generate pivot table for ind_off for hali and sum of misses and makes

import pandas as pd
pivot_table_ind_off = pd.pivot_table(ind_off, values=['misses', 'makes'], index=['hali', 'period_min'], aggfunc='sum').reset_index()
pivot_table_ind_off['shots'] = pivot_table_ind_off['misses'] + pivot_table_ind_off['makes']
pivot_table_ind_off['shot_pct'] = pivot_table_ind_off['makes'] / pivot_table_ind_off['shots']
pivot_table_ind_off
# Out:
#       hali period_min  makes  misses  shots  shot_pct
# 0    False        1_0     59      76    135  0.437037
# 1    False        1_1     83     113    196  0.423469
# 2    False       1_10    190     223    413  0.460048
# 3    False       1_11    191     226    417  0.458034
# 4    False       1_12     14      44     58  0.241379
# ..     ...        ...    ...     ...    ...       ...
# 111   True        5_1      4       6     10  0.400000
# 112   True        5_2      4       5      9  0.444444
# 113   True        5_3      6       6     12  0.500000
# 114   True        5_4      3       7     10  0.300000
# 115   True        5_5      0       2      2  0.000000
#
# [116 rows x 6 columns]

# %%
plt.figure(figsize=(12, 6))

for hali_val in pivot_table_ind_off['hali'].unique():
  subset = pivot_table_ind_off[pivot_table_ind_off['hali'] == hali_val]
  sns.kdeplot(subset['shot_pct'], label=f'Tyrese Haliburton On Court: {hali_val}')

avg_shot_pct = pivot_table_ind_off['shot_pct'].mean()
plt.axvline(x=avg_shot_pct, color='red', linestyle='--', label=f'Average Shot Percentage: {avg_shot_pct:.2f}')

plt.xlabel('Shot Percentage')
plt.xlim(0, 1)
plt.ylabel('Density')
plt.ylim(0, 8)
plt.title('Shot Percentage By Minute Distribution With and Without Tyrese Haliburton')
plt.legend()
plt.show()

# %%
# prompt: add a t-test that compares the shot percentage with haliburton on the court vs haliburton not on court

from scipy.stats import ttest_ind

# Separate shot percentages based on Haliburton's presence
hali_on_court = pivot_table_ind_off[pivot_table_ind_off['hali'] == True]['shot_pct']
hali_off_court = pivot_table_ind_off[pivot_table_ind_off['hali'] == False]['shot_pct']

# Perform the t-test
t_statistic, p_value = ttest_ind(hali_on_court, hali_off_court)

print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("There is a statistically significant difference in shot percentage with and without Haliburton on the court.")
else:
    print("There is no statistically significant difference in shot percentage with and without Haliburton on the court.")
# Out:
# T-statistic: 1.0512197040719367
# P-value: 0.2953809440280072
# There is no statistically significant difference in shot percentage with and without Haliburton on the court.

# %%
hali_off_2224 = ind_off[(ind_off.hali) & (ind_off.data_set.astype(str).apply(lambda x: '23' in x))].copy()
# get only plays where booker is involved in the action
hali_off_2224 = hali_off_2224[hali_off_2224.description.apply(lambda x: 'Haliburton' in x)]

# %%
hali_off_2224['hali_shot'] = (hali_off_2224.description.apply(lambda x: '(Haliburton' not in x)) \
      & (hali_off_2224['type'].apply(lambda x: 'shot' in x or 'layup' in x or 'fadeaway' in x or 'dunk' in x))

# %%
hali_shot_2224 = hali_off_2224[(hali_off_2224.hali_shot) | (hali_off_2224['type'].apply(lambda x: 'free throw' in x or 'technical' in x))].copy()
hali_shot_2224['FT'] = hali_shot_2224['type'].apply(lambda x: 'free throw' in x or 'technical' in x)
hali_shot_2224['FT_make'] = (hali_shot_2224.FT) & (hali_shot_2224.description.apply(lambda x: 'MISS' not in x))
hali_shot_2224['shot'] = ~hali_shot_2224.FT
hali_shot_2224['shot_make'] = hali_shot_2224.shot & (hali_shot_2224.description.apply(lambda x: 'MISS' not in x))

# %%
hali_shot_2224['3PT'] = ((hali_shot_2224.shot_distance >= 22) & (hali_shot_2224['type'].apply(lambda x: '3pt' in x)))
hali_shot_2224['midrange'] = ((hali_shot_2224.shot_distance <= 24) & (hali_shot_2224.shot_distance > 10) & (hali_shot_2224['type'].apply(lambda x: '3pt' not in x)))
hali_shot_2224['close'] = (hali_shot_2224.shot_distance <= 10)

# %%
pivot_table_shot_hali = pd.pivot_table(hali_shot_2224, values=['shot', 'shot_make'],
                                              index=['3PT', 'midrange', 'close', 'period_min'],
                                              aggfunc='sum').reset_index()
pivot_table_shot_hali
# Out:
#        3PT  midrange  close period_min  shot  shot_make
# 0    False     False  False        1_1     0          0
# 1    False     False  False       1_10     0          0
# 2    False     False  False       1_11     0          0
# 3    False     False  False        1_2     0          0
# 4    False     False  False        1_3     0          0
# ..     ...       ...    ...        ...   ...        ...
# 190   True     False  False        4_8    23         10
# 191   True     False  False        4_9    29         15
# 192   True     False  False        5_3     2          1
# 193   True     False  False        5_4     2          1
# 194   True     False  False        5_5     1          0
#
# [195 rows x 6 columns]

# %%
# prompt: using pivot_table_shot_hali, split into 3 plots, one for each shot category

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 6))

for i, shot_type in enumerate(['3PT', 'midrange', 'close']):
  plt.subplot(1, 3, i + 1)
  subset = pivot_table_shot_hali[pivot_table_shot_hali[shot_type]]
  if not subset.empty:
      shot_pct = subset['shot_make'] / subset['shot']
      sns.kdeplot(subset['shot'], bw_adjust=0.7, label=f'{shot_type}')
  plt.xlabel('Shot Count')
  plt.xlim(0, 30)
  plt.ylabel('Proportion')
  plt.title(f'Haliburton {shot_type} Shot Distribution')
  plt.legend()

plt.tight_layout()
plt.show()
